# %% [markdown]
# Read Collection Pickle

# %%
import numpy as np
import pandas as pd

# 1) Download the collection set from the Gitlab repository: https://gitlab.com/checkthat_lab/clef2025-checkthat-lab/-/tree/main/task4?ref_type=heads
# 2) Drag and drop the downloaded file to the "Files" section (left vertical menu on Colab)
# 3) Modify the path to your local file path
PATH_COLLECTION_DATA = 'data/subtask_4b/subtask4b_collection_data.pkl' #MODIFY PATH
df_collection = pd.read_pickle(PATH_COLLECTION_DATA)
df_collection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7718 entries, 162 to 1056448
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cord_uid          7718 non-null   object
#  1   source_x          7718 non-null   object
#  2   title             7718 non-null   object
#  3   doi               7677 non-null   object
#  4   pmcid             4959 non-null   object
#  5   pubmed_id         6233 non-null   object
#  6   license           7718 non-null   object
#  7   abstract          7718 non-null   object
#  8   publish_time      7715 non-null   object
#  9   authors           7674 non-null   object
#  10  journal           6668 non-null   object
#  11  mag_id            0 non-null      float64
#  12  who_covidence_id  528 non-null    object
#  13  arxiv_id          20 non-null     object
#  14  label             7718 non-null   object
#  15  time              7715 non-null   datetime64[ns]
#  16  timet             7718 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(14)
# memory usage: 1.1+ MB

# %%
df_collection.head()
# Out:
#       cord_uid source_x                                              title  \
# 162   umvrwgaw      PMC  Professional and Home-Made Face Masks Reduce E...
# 611   spiud6ok      PMC                               The Failure of R (0)
# 918   aclzp3iy      PMC  Pulmonary sequelae in a patient recovered from...
# 993   ycxyn2a2      PMC  What was the primary mode of smallpox transmis...
# 1053  zxe95qy9      PMC  Lessons from the History of Quarantine, from P...
#
#                                doi       pmcid pubmed_id      license  \
# 162   10.1371/journal.pone.0002618  PMC2440799  18612429        cc-by
# 611            10.1155/2011/527610  PMC3157160  21860658        cc-by
# 918        10.4103/0970-2113.99118  PMC3424870  22919170  cc-by-nc-sa
# 993       10.3389/fcimb.2012.00150  PMC3509329  23226686        cc-by
# 1053        10.3201/eid1902.120312  PMC3559034  23343512        no-cc
#
#                                                abstract publish_time  \
# 162   BACKGROUND: Governments are preparing for a po...   2008-07-09
# 611   The basic reproductive ratio, R (0), is one of...   2011-08-16
# 918   The pandemic of swine flu (H1N1) influenza spr...         2012
# 993   The mode of infection transmission has profoun...   2012-11-29
# 1053  In the new millennium, the centuries-old strat...   2013-02-03
#
#                                                 authors  \
# 162   van der Sande, Marianne; Teunis, Peter; Sabel,...
# 611       Li, Jing; Blakeley, Daniel; Smith?, Robert J.
# 918   Singh, Virendra; Sharma, Bharat Bhushan; Patel...
# 993                                   Milton, Donald K.
# 1053                                  Tognotti, Eugenia
#
#                           journal  mag_id who_covidence_id arxiv_id     label  \
# 162                      PLoS One     NaN              NaN      NaN  umvrwgaw
# 611       Comput Math Methods Med     NaN              NaN      NaN  spiud6ok
# 918                    Lung India     NaN              NaN      NaN  aclzp3iy
# 993   Front Cell Infect Microbiol     NaN              NaN      NaN  ycxyn2a2
# 1053             Emerg Infect Dis     NaN              NaN      NaN  zxe95qy9
#
#            time       timet
# 162  2008-07-09  1215561600
# 611  2011-08-16  1313452800
# 918  2012-01-01  1325376000
# 993  2012-11-29  1354147200
# 1053 2013-02-03  1359849600

# %% [markdown]
# Process Query File

# %%
# 1) Download the query tweets from the Gitlab repository: https://gitlab.com/checkthat_lab/clef2025-checkthat-lab/-/tree/main/task4?ref_type=heads
# 2) Drag and drop the downloaded file to the "Files" section (left vertical menu on Colab)
# 3) Modify the path to your local file path
PATH_QUERY_DATA = 'data/subtask_4b/subtask4b_query_tweets.tsv' #MODIFY PATH
df_query = pd.read_csv(PATH_QUERY_DATA, sep = '\t')
df_query.head()
# Out:
#                                           tweet_text  cord_uid
# 0  Oral care in rehabilitation medicine: oral vul...  htlvpvz5
# 1  this study isn't receiving sufficient attentio...  4kfl29ul
# 2  thanks, xi jinping. a reminder that this study...  jtwb17u8
# 3  Taiwan - a population of 23 million has had ju...  0w9k8iy1
# 4  Obtaining a diagnosis of autism in lower incom...  tiqksd69

# %%
df_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14253 entries, 0 to 14252
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  14253 non-null  object
#  1   cord_uid    14253 non-null  object
# dtypes: object(2)
# memory usage: 222.8+ KB

# %%
from sklearn.model_selection import train_test_split

TRAINING_SPLIT_SIZE = 0.8

df_training_set, df_test_set = train_test_split(df_query, test_size=0.2)

df_test_set.to_csv('data/eval-tweets/eval-tweets.tsv',sep='\t')

print("--- Training")
df_training_set.info()
print("--- Test")
df_test_set.info()
# Out:
# --- Training
# <class 'pandas.core.frame.DataFrame'>
# Index: 11402 entries, 5473 to 8488
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  11402 non-null  object
#  1   cord_uid    11402 non-null  object
# dtypes: object(2)
# memory usage: 267.2+ KB
# --- Test
# <class 'pandas.core.frame.DataFrame'>
# Index: 2851 entries, 11163 to 13128
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  2851 non-null   object
#  1   cord_uid    2851 non-null   object
# dtypes: object(2)
# memory usage: 66.8+ KB

# %%
df_training_set.head()
# Out:
#                                               tweet_text  cord_uid
# 5473   Unless SARS-CoV-2 is allowed to continue to sp...  2iupb6gj
# 3840   Here's a link to the study rather than a brief...  b4161ynv
# 10243  1000 unvaccinated people following vaccination...  r5v2gi3v
# 14131  online now: age-related changes in the local e...  909kmcwv
# 11045  Chronic exposure to #cigarette smoke, a risk f...  xziy99uo

# %%
df_collection.head()
# Out:
#       cord_uid source_x                                              title  \
# 162   umvrwgaw      PMC  Professional and Home-Made Face Masks Reduce E...
# 611   spiud6ok      PMC                               The Failure of R (0)
# 918   aclzp3iy      PMC  Pulmonary sequelae in a patient recovered from...
# 993   ycxyn2a2      PMC  What was the primary mode of smallpox transmis...
# 1053  zxe95qy9      PMC  Lessons from the History of Quarantine, from P...
#
#                                doi       pmcid pubmed_id      license  \
# 162   10.1371/journal.pone.0002618  PMC2440799  18612429        cc-by
# 611            10.1155/2011/527610  PMC3157160  21860658        cc-by
# 918        10.4103/0970-2113.99118  PMC3424870  22919170  cc-by-nc-sa
# 993       10.3389/fcimb.2012.00150  PMC3509329  23226686        cc-by
# 1053        10.3201/eid1902.120312  PMC3559034  23343512        no-cc
#
#                                                abstract publish_time  \
# 162   BACKGROUND: Governments are preparing for a po...   2008-07-09
# 611   The basic reproductive ratio, R (0), is one of...   2011-08-16
# 918   The pandemic of swine flu (H1N1) influenza spr...         2012
# 993   The mode of infection transmission has profoun...   2012-11-29
# 1053  In the new millennium, the centuries-old strat...   2013-02-03
#
#                                                 authors  \
# 162   van der Sande, Marianne; Teunis, Peter; Sabel,...
# 611       Li, Jing; Blakeley, Daniel; Smith?, Robert J.
# 918   Singh, Virendra; Sharma, Bharat Bhushan; Patel...
# 993                                   Milton, Donald K.
# 1053                                  Tognotti, Eugenia
#
#                           journal  mag_id who_covidence_id arxiv_id     label  \
# 162                      PLoS One     NaN              NaN      NaN  umvrwgaw
# 611       Comput Math Methods Med     NaN              NaN      NaN  spiud6ok
# 918                    Lung India     NaN              NaN      NaN  aclzp3iy
# 993   Front Cell Infect Microbiol     NaN              NaN      NaN  ycxyn2a2
# 1053             Emerg Infect Dis     NaN              NaN      NaN  zxe95qy9
#
#            time       timet
# 162  2008-07-09  1215561600
# 611  2011-08-16  1313452800
# 918  2012-01-01  1325376000
# 993  2012-11-29  1354147200
# 1053 2013-02-03  1359849600

# %%
positive_train_data = pd.DataFrame(columns=df_collection.columns)
query = []
for idx, row in df_training_set.iterrows():
    entry_cord_id = row.cord_uid
    query.append(row.tweet_text)
    positive_train_data = pd.concat([positive_train_data, df_collection.loc[df_collection["cord_uid"] == entry_cord_id]], ignore_index=True)

cls = [1] * len(positive_train_data)
positive_train_data["query"] = query
positive_train_data["label"] = cls
positive_train_data.info()
# Out:
# /tmp/ipykernel_10291/2860249657.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   positive_train_data = pd.concat([positive_train_data, df_collection.loc[df_collection["cord_uid"] == entry_cord_id]], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11402 entries, 0 to 11401
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cord_uid          11402 non-null  object
#  1   source_x          11402 non-null  object
#  2   title             11402 non-null  object
#  3   doi               11342 non-null  object
#  4   pmcid             7526 non-null   object
#  5   pubmed_id         9373 non-null   object
#  6   license           11402 non-null  object
#  7   abstract          11402 non-null  object
#  8   publish_time      11399 non-null  object
#  9   authors           11339 non-null  object
#  10  journal           9886 non-null   object
#  11  mag_id            0 non-null      object
#  12  who_covidence_id  646 non-null    object
#  13  arxiv_id          42 non-null     object
#  14  label             11402 non-null  int64
#  15  time              11399 non-null  datetime64[ns]
#  16  timet             11402 non-null  object
#  17  query             11402 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(16)
# memory usage: 1.6+ MB

# %%
positive_test_data = pd.DataFrame(columns=df_collection.columns)
query = []
for idx, row in df_test_set.iterrows():
    entry_cord_id = row.cord_uid
    query.append(row.tweet_text)
    positive_test_data = pd.concat([positive_test_data, df_collection.loc[df_collection["cord_uid"] == entry_cord_id]], ignore_index=True)

cls = [1] * len(positive_test_data)
positive_test_data["label"] = cls
positive_test_data["query"] = query
positive_test_data.head()
# Out:
# /tmp/ipykernel_10291/1898745850.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   positive_test_data = pd.concat([positive_test_data, df_collection.loc[df_collection["cord_uid"] == entry_cord_id]], ignore_index=True)
#    cord_uid      source_x                                              title  \
# 0  tffhk1hy           PMC  Borrelia burgdorferi infection modifies protei...
# 1  wq92nfnd  MedRxiv; WHO  Slight reduction in SARS-CoV-2 exposure viral ...
# 2  e85xdrcw  MedRxiv; WHO  Early evaluation of the Wuhan City travel rest...
# 3  aefzogn3  Medline; PMC  Neutralization of SARS-CoV-2 lineage B.1.1.7 p...
# 4  4gr6i8rf  MedRxiv; WHO  Herd immunity thresholds for SARS-CoV-2 estima...
#
#                            doi       pmcid pubmed_id  license  \
# 0   10.1186/s12864-021-07429-0  PMC7930271  33663385    cc-by
# 1  10.1101/2020.09.13.20193508         NaN       NaN  medrxiv
# 2  10.1101/2020.01.30.20019844         NaN       NaN    cc-by
# 3      10.1126/science.abg6105  PMC7971771  33514629    cc-by
# 4  10.1101/2020.07.23.20160762         NaN       NaN  medrxiv
#
#                                             abstract publish_time  \
# 0  BACKGROUND: Lyme disease (LD) caused by Borrel...   2021-03-04
# 1  Masks are a vital tool for limiting SARS-CoV-2...   2020-09-14
# 2  Respiratory illness caused by a novel coronavi...   2020-02-02
# 3  Recently, a new severe acute respiratory syndr...   2021-03-12
# 4  As severe acute respiratory syndrome coronavir...   2020-07-24
#
#                                              authors       journal mag_id  \
# 0  Kim, Tae Kwon; Tirloni, Lucas; Bencosme-Cuevas...  BMC Genomics    NaN
# 1  Goyal, A.; Reeves, D. B.; Cardozo Ojeda, E. F....           NaN    NaN
# 2  Tian, Huaiyu; Liu, Yonghong; Li, Yidan; Wu, Ch...           NaN    NaN
# 3  Muik, Alexander; Wallisch, Ann-Kathrin; Sänger...       Science    NaN
# 4  Aguas, R.; Corder, R. M.; King, J. G.; Goncalv...           NaN    NaN
#
#   who_covidence_id arxiv_id  label       time       timet  \
# 0              NaN      NaN      1 2021-03-04  1614816000
# 1              NaN      NaN      1 2020-09-14  1600041600
# 2        #20019844      NaN      1 2020-02-02  1580601600
# 3              NaN      NaN      1 2021-03-12  1615507200
# 4              NaN      NaN      1 2020-07-24  1595548800
#
#                                                query
# 0  does the #lyme bacteria "colonize"? interestin...
# 1  nice preprint from the outstanding dr. joshua ...
# 2  an analysis by  and others concluded that halt...
# 3  Neutralization of SARS-CoV-2 lineage B.1.1.7 p...
# 4  that T-cell immunity suggests we may already h...

# %%
NUM_NEGATIVE_SAMPLES = 5

negative_train_data = pd.DataFrame(columns=df_collection.columns)
query = []

for idx, row in df_training_set.iterrows():
    entry_cord_id = row.cord_uid
    repeated_queries = [row.tweet_text] * NUM_NEGATIVE_SAMPLES
    query += repeated_queries
    negative_samples = df_collection.loc[df_collection["cord_uid"] != entry_cord_id]
    negative_samples = negative_samples.sample(NUM_NEGATIVE_SAMPLES)
    negative_train_data = pd.concat([negative_train_data, negative_samples], ignore_index=True)

cls = [0] * len(negative_train_data)
negative_train_data["label"] = cls
negative_train_data["query"] = query
negative_train_data.head()
# Out:
# /tmp/ipykernel_10291/1195494629.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   negative_train_data = pd.concat([negative_train_data, negative_samples], ignore_index=True)
#    cord_uid                    source_x  \
# 0  fiicxnty                Medline; PMC
# 1  2un9aggj  MedRxiv; Medline; PMC; WHO
# 2  a702kkx0           Medline; PMC; WHO
# 3  bggera4e           Medline; PMC; WHO
# 4  lhvgsmgf                MedRxiv; WHO
#
#                                                title  \
# 0  Antimicrobial Resistance as a Hidden Menace Lu...
# 1  ACE2 Expression is Increased in the Lungs of P...
# 2  Expiring Eviction Moratoriums and COVID-19 Inc...
# 3  Prolonged and extended impacts of SARS-CoV-2 o...
# 4  Guillain-Barre Syndrome after COVID-19 Vaccina...
#
#                            doi       pmcid pubmed_id   license  \
# 0    10.3389/fmicb.2020.590683  PMC7769770  33384670     cc-by
# 1  10.1101/2020.03.21.20040261  PMC7276054  32511627     no-cc
# 2          10.1093/aje/kwab196  PMC8634574  34309643  cc-by-nc
# 3   10.1038/s41598-022-09731-7  PMC8987081  35388072     cc-by
# 4  10.1101/2021.12.03.21266419         NaN       NaN   medrxiv
#
#                                             abstract publish_time  \
# 0  The severe acute respiratory syndrome coronavi...   2020-12-15
# 1  The pandemic caused by the Severe Acute Respir...   2020-03-27
# 2  The coronavirus disease 2019 (COVID-19) pandem...   2021-07-26
# 3  The impact of SARS-CoV-2 on the olfactory path...   2022-04-06
# 4  Importance: Post-authorization monitoring of v...   2021-12-05
#
#                                              authors          journal mag_id  \
# 0  Rezasoltani, Sama; Yadegar, Abbas; Hatami, Beh...  Front Microbiol    NaN
# 1  Pinto, Bruna G.G.; Oliveira, Antonio E.R.; Sin...          medRxiv    NaN
# 2  Leifheit, Kathryn M; Linton, Sabriya L; Raifma...   Am J Epidemiol    NaN
# 3  Kishimoto-Urata, Megumi; Urata, Shinji; Kagoya...          Sci Rep    NaN
# 4  Hanson, K. E.; Goddard, K.; Lewis, N.; Fireman...              NaN    NaN
#
#   who_covidence_id arxiv_id  label       time       timet  \
# 0              NaN      NaN      0 2020-12-15  1607990400
# 1              NaN      NaN      0 2020-03-27  1585267200
# 2              NaN      NaN      0 2021-07-26  1627257600
# 3              NaN      NaN      0 2022-04-06  1649203200
# 4              NaN      NaN      0 2021-12-05  1638662400
#
#                                                query
# 0  Unless SARS-CoV-2 is allowed to continue to sp...
# 1  Unless SARS-CoV-2 is allowed to continue to sp...
# 2  Unless SARS-CoV-2 is allowed to continue to sp...
# 3  Unless SARS-CoV-2 is allowed to continue to sp...
# 4  Unless SARS-CoV-2 is allowed to continue to sp...

# %%
NUM_NEGATIVE_SAMPLES = 5

negative_test_data = pd.DataFrame(columns=df_collection.columns)
query = []

for idx, row in df_test_set.iterrows():
    entry_cord_id = row.cord_uid
    repeated_queries = [row.tweet_text] * NUM_NEGATIVE_SAMPLES
    query += repeated_queries
    negative_samples = df_collection.loc[df_collection["cord_uid"] != entry_cord_id]
    negative_samples = negative_samples.sample(NUM_NEGATIVE_SAMPLES)
    negative_test_data = pd.concat([negative_test_data, negative_samples], ignore_index=True)

cls = [0] * len(negative_test_data)
negative_test_data["label"] = cls
negative_test_data["query"] = query
negative_test_data.head()
# Out:
# /tmp/ipykernel_10291/3514562953.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   negative_test_data = pd.concat([negative_test_data, negative_samples], ignore_index=True)
#    cord_uid                source_x  \
# 0  s245n3qw       Medline; PMC; WHO
# 1  jbzqem3m  Elsevier; Medline; PMC
# 2  az7f7zgr            Medline; PMC
# 3  vww8d1ew            Medline; PMC
# 4  szxz9jve   MedRxiv; Medline; WHO
#
#                                                title  \
# 0  COVID-19: Up to 82% critically ill patients ha...
# 1  Viral calciomics: Interplays between Ca(2+) an...
# 2  Estimated Inactivation of Coronaviruses by Sol...
# 3  Transmission Dynamics of COVID-19 Outbreaks As...
# 4  Plitidepsin has a positive therapeutic index i...
#
#                            doi       pmcid pubmed_id   license  \
# 0   10.1186/s12937-021-00727-z  PMC8269403  34243781     cc-by
# 1   10.1016/j.ceca.2009.05.005  PMC3449087  19535138  green-oa
# 2            10.1111/php.13293  PMC7300806  32502327     no-cc
# 3       10.15585/mmwr.mm6937e3  PMC7498176  32941418     cc-by
# 4  10.1101/2021.05.25.21257505         NaN  34075384   medrxiv
#
#                                             abstract publish_time  \
# 0  There are limited proven therapeutic options f...   2021-07-09
# 1  Ca(2+) is one of the most universal and versat...   2009-07-01
# 2  Using a model developed for estimating solar i...   2020-06-05
# 3  Reports suggest that children aged ≥10 years c...   2020-09-18
# 4  Plitidepsin is a marine-derived cyclic-peptide...   2021-05-25
#
#                                              authors  \
# 0  Tomasa-Irriguible, Teresa Maria; Bielsa-Berroc...
# 1        Zhou, Yubin; Frey, Teryl K.; Yang, Jenny J.
# 2             Sagripanti, Jose‐Luis; Lytle, C. David
# 3  Lopez, Adriana S.; Hill, Mary; Antezano, Jessi...
# 4  Varona, J. F.; Landete, P.; Lopez-Martin, J. A...
#
#                                              journal mag_id who_covidence_id  \
# 0                                             Nutr J    NaN              NaN
# 1                                       Cell Calcium    NaN              NaN
# 2                                Photochem Photobiol    NaN              NaN
# 3                          MMWR Morb Mortal Wkly Rep    NaN              NaN
# 4  medRxiv : the preprint server for health sciences    NaN              NaN
#
#   arxiv_id  label       time       timet  \
# 0      NaN      0 2021-07-09  1625788800
# 1      NaN      0 2009-07-01  1246406400
# 2      NaN      0 2020-06-05  1591315200
# 3      NaN      0 2020-09-18  1600387200
# 4      NaN      0 2021-05-25  1621900800
#
#                                                query
# 0  does the #lyme bacteria "colonize"? interestin...
# 1  does the #lyme bacteria "colonize"? interestin...
# 2  does the #lyme bacteria "colonize"? interestin...
# 3  does the #lyme bacteria "colonize"? interestin...
# 4  does the #lyme bacteria "colonize"? interestin...

# %%
mixed_training_set = pd.concat([negative_train_data, positive_train_data], ignore_index=True)
mixed_training_set.info()

mixed_training_set.to_csv('data/model-data/train/tweets-query-pairs.tsv',sep='\t')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68412 entries, 0 to 68411
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cord_uid          68412 non-null  object
#  1   source_x          68412 non-null  object
#  2   title             68412 non-null  object
#  3   doi               68066 non-null  object
#  4   pmcid             44114 non-null  object
#  5   pubmed_id         55487 non-null  object
#  6   license           68412 non-null  object
#  7   abstract          68412 non-null  object
#  8   publish_time      68380 non-null  object
#  9   authors           68026 non-null  object
#  10  journal           59115 non-null  object
#  11  mag_id            0 non-null      object
#  12  who_covidence_id  4634 non-null   object
#  13  arxiv_id          197 non-null    object
#  14  label             68412 non-null  int64
#  15  time              68380 non-null  datetime64[ns]
#  16  timet             68412 non-null  object
#  17  query             68412 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(16)
# memory usage: 9.4+ MB

# %%
mixed_test_set = pd.concat([negative_test_data, positive_test_data], ignore_index=True)
mixed_test_set.info()

mixed_test_set.to_csv('data/model-data/test/tweets-query-pairs.tsv',sep='\t')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17106 entries, 0 to 17105
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cord_uid          17106 non-null  object
#  1   source_x          17106 non-null  object
#  2   title             17106 non-null  object
#  3   doi               17024 non-null  object
#  4   pmcid             10958 non-null  object
#  5   pubmed_id         13756 non-null  object
#  6   license           17106 non-null  object
#  7   abstract          17106 non-null  object
#  8   publish_time      17094 non-null  object
#  9   authors           17023 non-null  object
#  10  journal           14718 non-null  object
#  11  mag_id            0 non-null      object
#  12  who_covidence_id  1152 non-null   object
#  13  arxiv_id          35 non-null     object
#  14  label             17106 non-null  int64
#  15  time              17094 non-null  datetime64[ns]
#  16  timet             17106 non-null  object
#  17  query             17106 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(16)
# memory usage: 2.3+ MB
