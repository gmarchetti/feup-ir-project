# %% [markdown]
# Read Collection Pickle

# %%
import numpy as np
import pandas as pd

# 1) Download the collection set from the Gitlab repository: https://gitlab.com/checkthat_lab/clef2025-checkthat-lab/-/tree/main/task4?ref_type=heads
# 2) Drag and drop the downloaded file to the "Files" section (left vertical menu on Colab)
# 3) Modify the path to your local file path
PATH_COLLECTION_DATA = '/home/guilherme/workspace/feup-ir-project/data/subtask_4b/subtask4b_collection_data.pkl' #MODIFY PATH
df_collection = pd.read_pickle(PATH_COLLECTION_DATA)
df_collection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7718 entries, 162 to 1056448
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cord_uid          7718 non-null   object
#  1   source_x          7718 non-null   object
#  2   title             7718 non-null   object
#  3   doi               7677 non-null   object
#  4   pmcid             4959 non-null   object
#  5   pubmed_id         6233 non-null   object
#  6   license           7718 non-null   object
#  7   abstract          7718 non-null   object
#  8   publish_time      7715 non-null   object
#  9   authors           7674 non-null   object
#  10  journal           6668 non-null   object
#  11  mag_id            0 non-null      float64
#  12  who_covidence_id  528 non-null    object
#  13  arxiv_id          20 non-null     object
#  14  label             7718 non-null   object
#  15  time              7715 non-null   datetime64[ns]
#  16  timet             7718 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(14)
# memory usage: 1.1+ MB

# %%
df_collection.head()
# Out:
#       cord_uid source_x                                              title  \
# 162   umvrwgaw      PMC  Professional and Home-Made Face Masks Reduce E...
# 611   spiud6ok      PMC                               The Failure of R (0)
# 918   aclzp3iy      PMC  Pulmonary sequelae in a patient recovered from...
# 993   ycxyn2a2      PMC  What was the primary mode of smallpox transmis...
# 1053  zxe95qy9      PMC  Lessons from the History of Quarantine, from P...
#
#                                doi       pmcid pubmed_id      license  \
# 162   10.1371/journal.pone.0002618  PMC2440799  18612429        cc-by
# 611            10.1155/2011/527610  PMC3157160  21860658        cc-by
# 918        10.4103/0970-2113.99118  PMC3424870  22919170  cc-by-nc-sa
# 993       10.3389/fcimb.2012.00150  PMC3509329  23226686        cc-by
# 1053        10.3201/eid1902.120312  PMC3559034  23343512        no-cc
#
#                                                abstract publish_time  \
# 162   BACKGROUND: Governments are preparing for a po...   2008-07-09
# 611   The basic reproductive ratio, R (0), is one of...   2011-08-16
# 918   The pandemic of swine flu (H1N1) influenza spr...         2012
# 993   The mode of infection transmission has profoun...   2012-11-29
# 1053  In the new millennium, the centuries-old strat...   2013-02-03
#
#                                                 authors  \
# 162   van der Sande, Marianne; Teunis, Peter; Sabel,...
# 611       Li, Jing; Blakeley, Daniel; Smith?, Robert J.
# 918   Singh, Virendra; Sharma, Bharat Bhushan; Patel...
# 993                                   Milton, Donald K.
# 1053                                  Tognotti, Eugenia
#
#                           journal  mag_id who_covidence_id arxiv_id     label  \
# 162                      PLoS One     NaN              NaN      NaN  umvrwgaw
# 611       Comput Math Methods Med     NaN              NaN      NaN  spiud6ok
# 918                    Lung India     NaN              NaN      NaN  aclzp3iy
# 993   Front Cell Infect Microbiol     NaN              NaN      NaN  ycxyn2a2
# 1053             Emerg Infect Dis     NaN              NaN      NaN  zxe95qy9
#
#            time       timet
# 162  2008-07-09  1215561600
# 611  2011-08-16  1313452800
# 918  2012-01-01  1325376000
# 993  2012-11-29  1354147200
# 1053 2013-02-03  1359849600

# %% [markdown]
# Process Query File

# %%
# 1) Download the query tweets from the Gitlab repository: https://gitlab.com/checkthat_lab/clef2025-checkthat-lab/-/tree/main/task4?ref_type=heads
# 2) Drag and drop the downloaded file to the "Files" section (left vertical menu on Colab)
# 3) Modify the path to your local file path
PATH_QUERY_DATA = '/home/guilherme/workspace/feup-ir-project/data/subtask_4b/subtask4b_query_tweets.tsv' #MODIFY PATH
df_query = pd.read_csv(PATH_QUERY_DATA, sep = '\t')
df_query.head()
# Out:
#                                           tweet_text  cord_uid
# 0  Oral care in rehabilitation medicine: oral vul...  htlvpvz5
# 1  this study isn't receiving sufficient attentio...  4kfl29ul
# 2  thanks, xi jinping. a reminder that this study...  jtwb17u8
# 3  Taiwan - a population of 23 million has had ju...  0w9k8iy1
# 4  Obtaining a diagnosis of autism in lower incom...  tiqksd69

# %%
df_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14253 entries, 0 to 14252
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  14253 non-null  object
#  1   cord_uid    14253 non-null  object
# dtypes: object(2)
# memory usage: 222.8+ KB

# %%
from sklearn.model_selection import train_test_split

TRAINING_SPLIT_SIZE = 0.8

df_training_set, df_test_set = train_test_split(df_query, test_size=0.2)

print("--- Training")
df_training_set.info()
print("--- Test")
df_test_set.info()
# Out:
# --- Training
# <class 'pandas.core.frame.DataFrame'>
# Index: 11402 entries, 967 to 737
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  11402 non-null  object
#  1   cord_uid    11402 non-null  object
# dtypes: object(2)
# memory usage: 267.2+ KB
# --- Test
# <class 'pandas.core.frame.DataFrame'>
# Index: 2851 entries, 11583 to 1434
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  2851 non-null   object
#  1   cord_uid    2851 non-null   object
# dtypes: object(2)
# memory usage: 66.8+ KB

# %%
df_training_set.head()
# Out:
#                                               tweet_text  cord_uid
# 967    A peer-reviewed study reveals no substantial a...  texmsvyt
# 1999   just read the section titled explanation... yo...  a7frertc
# 1081   A University of Washington study discovered th...  lp0r7j5c
# 2304   In this convenience sample survey disseminated...  iucrorzh
# 13517  Long Covid - innate versus vaccine immunity di...  ivue7zob

# %%
df_collection.head()
# Out:
#       cord_uid source_x                                              title  \
# 162   umvrwgaw      PMC  Professional and Home-Made Face Masks Reduce E...
# 611   spiud6ok      PMC                               The Failure of R (0)
# 918   aclzp3iy      PMC  Pulmonary sequelae in a patient recovered from...
# 993   ycxyn2a2      PMC  What was the primary mode of smallpox transmis...
# 1053  zxe95qy9      PMC  Lessons from the History of Quarantine, from P...
#
#                                doi       pmcid pubmed_id      license  \
# 162   10.1371/journal.pone.0002618  PMC2440799  18612429        cc-by
# 611            10.1155/2011/527610  PMC3157160  21860658        cc-by
# 918        10.4103/0970-2113.99118  PMC3424870  22919170  cc-by-nc-sa
# 993       10.3389/fcimb.2012.00150  PMC3509329  23226686        cc-by
# 1053        10.3201/eid1902.120312  PMC3559034  23343512        no-cc
#
#                                                abstract publish_time  \
# 162   BACKGROUND: Governments are preparing for a po...   2008-07-09
# 611   The basic reproductive ratio, R (0), is one of...   2011-08-16
# 918   The pandemic of swine flu (H1N1) influenza spr...         2012
# 993   The mode of infection transmission has profoun...   2012-11-29
# 1053  In the new millennium, the centuries-old strat...   2013-02-03
#
#                                                 authors  \
# 162   van der Sande, Marianne; Teunis, Peter; Sabel,...
# 611       Li, Jing; Blakeley, Daniel; Smith?, Robert J.
# 918   Singh, Virendra; Sharma, Bharat Bhushan; Patel...
# 993                                   Milton, Donald K.
# 1053                                  Tognotti, Eugenia
#
#                           journal  mag_id who_covidence_id arxiv_id     label  \
# 162                      PLoS One     NaN              NaN      NaN  umvrwgaw
# 611       Comput Math Methods Med     NaN              NaN      NaN  spiud6ok
# 918                    Lung India     NaN              NaN      NaN  aclzp3iy
# 993   Front Cell Infect Microbiol     NaN              NaN      NaN  ycxyn2a2
# 1053             Emerg Infect Dis     NaN              NaN      NaN  zxe95qy9
#
#            time       timet
# 162  2008-07-09  1215561600
# 611  2011-08-16  1313452800
# 918  2012-01-01  1325376000
# 993  2012-11-29  1354147200
# 1053 2013-02-03  1359849600

# %%
positive_train_data = pd.DataFrame(columns=df_collection.columns)
query = []
for idx, row in df_training_set.iterrows():
    entry_cord_id = row.cord_uid
    query.append(row.tweet_text)
    positive_train_data = pd.concat([positive_train_data, df_collection.loc[df_collection["cord_uid"] == entry_cord_id]], ignore_index=True)

cls = [1] * len(positive_train_data)
positive_train_data["label"] = cls
positive_train_data["query"] = query
positive_train_data.info()
# Out:
# /tmp/ipykernel_4039/2149394839.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   positive_train_data = pd.concat([positive_train_data, df_collection.loc[df_collection["cord_uid"] == entry_cord_id]], ignore_index=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11402 entries, 0 to 11401
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cord_uid          11402 non-null  object
#  1   source_x          11402 non-null  object
#  2   title             11402 non-null  object
#  3   doi               11349 non-null  object
#  4   pmcid             7540 non-null   object
#  5   pubmed_id         9382 non-null   object
#  6   license           11402 non-null  object
#  7   abstract          11402 non-null  object
#  8   publish_time      11398 non-null  object
#  9   authors           11334 non-null  object
#  10  journal           9892 non-null   object
#  11  mag_id            0 non-null      object
#  12  who_covidence_id  637 non-null    object
#  13  arxiv_id          43 non-null     object
#  14  label             11402 non-null  int64
#  15  time              11398 non-null  datetime64[ns]
#  16  timet             11402 non-null  object
#  17  query             11402 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(16)
# memory usage: 1.6+ MB

# %%
positive_test_data = pd.DataFrame(columns=df_collection.columns)
query = []
for idx, row in df_test_set.iterrows():
    entry_cord_id = row.cord_uid
    query.append(row.tweet_text)
    positive_test_data = pd.concat([positive_test_data, df_collection.loc[df_collection["cord_uid"] == entry_cord_id]], ignore_index=True)

cls = [1] * len(positive_test_data)
positive_test_data["label"] = cls
positive_test_data["query"] = query
positive_test_data.head()
# Out:
# /tmp/ipykernel_4039/1898745850.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   positive_test_data = pd.concat([positive_test_data, df_collection.loc[df_collection["cord_uid"] == entry_cord_id]], ignore_index=True)
#    cord_uid                source_x  \
# 0  ef3warsh                 Medline
# 1  jk37ej4c            MedRxiv; WHO
# 2  4ylt5rhg                 MedRxiv
# 3  op1d2o5x  Elsevier; Medline; PMC
# 4  t4y1ylb3                 MedRxiv
#
#                                                title  \
# 0  Nonpharmaceutical Measures for Pandemic Influe...
# 1                  Indoor transmission of SARS-CoV-2
# 2  Significant reduction in humoral immunity amon...
# 3  The perfect storm: A Case of COVID-19 infectio...
# 4  Comparing SARS-CoV-2 natural immunity to vacci...
#
#                            doi       pmcid pubmed_id  license  \
# 0       10.3201/eid2605.190994         NaN  32027586    cc-by
# 1  10.1101/2020.04.04.20053058         NaN       NaN  medrxiv
# 2  10.1101/2021.08.15.21262067         NaN       NaN  medrxiv
# 3   10.1016/j.rmcr.2020.101306  PMC7687405  33251101    no-cc
# 4  10.1101/2021.08.24.21262415         NaN       NaN  medrxiv
#
#                                             abstract publish_time  \
# 0  There were 3 influenza pandemics in the 20th c...   2020-05-17
# 1  Background: By early April 2020, the COVID-19 ...   2020-04-07
# 2  CoV-2 vaccination; most NH residents received ...   2021-08-18
# 3  COVID-19 and EVALI share imaging findings and ...   2020-11-25
# 4  Background: Reports of waning vaccine-induced ...   2021-08-25
#
#                                              authors  \
# 0  Xiao, Jingyi; Shiu, Eunice Y C; Gao, Huizhi; W...
# 1  Qian, Hua; Miao, Te; LIU, Li; Zheng, Xiaohong;...
# 2  Canaday, D. H.; Oyebanji, O.; Keresztesy, D.; ...
# 3  Bozkanat, Kubra Melike; Rao, Devika; Lieu, Tif...
# 4  Gazit, S.; Shlezinger, R.; Perez, G.; Lotan, R...
#
#                         journal mag_id who_covidence_id arxiv_id  label  \
# 0  Emerging infectious diseases    NaN              NaN      NaN      1
# 1                           NaN    NaN              NaN      NaN      1
# 2                           NaN    NaN              NaN      NaN      1
# 3           Respir Med Case Rep    NaN              NaN      NaN      1
# 4                           NaN    NaN              NaN      NaN      1
#
#         time       timet                                              query
# 0 2020-05-17  1589673600  5. "we did not discover evidence that surgical...
# 1 2020-04-07  1586217600  A Chinese contact tracing study examining over...
# 2 2021-08-18  1629244800  You're 5x more likely to experience a complica...
# 3 2020-11-25  1606262400  ..a propensity for severe c19, similar to that...
# 4 2021-08-25  1629849600  does it?'sars-cov-2-naïve vaccinees had a 13.0...

# %%
NUM_NEGATIVE_SAMPLES = 5

negative_train_data = pd.DataFrame(columns=df_collection.columns)
query = []

for idx, row in df_training_set.iterrows():
    entry_cord_id = row.cord_uid
    repeated_queries = [row.tweet_text] * NUM_NEGATIVE_SAMPLES
    query += repeated_queries
    negative_samples = df_collection.loc[df_collection["cord_uid"] != entry_cord_id]
    negative_samples = negative_samples.sample(NUM_NEGATIVE_SAMPLES)
    negative_train_data = pd.concat([negative_train_data, negative_samples], ignore_index=True)

cls = [0] * len(negative_train_data)
negative_train_data["label"] = cls
negative_train_data["query"] = query
negative_train_data.head()
# Out:
# /tmp/ipykernel_4039/1195494629.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   negative_train_data = pd.concat([negative_train_data, negative_samples], ignore_index=True)
#    cord_uid                     source_x  \
# 0  s9lkvzpo                 BioRxiv; WHO
# 1  vnyly6uy  Elsevier; Medline; PMC; WHO
# 2  gs9lga7d                 Medline; PMC
# 3  z65wm00n                          WHO
# 4  br33p9xd                 Medline; PMC
#
#                                                title  \
# 0  Evidence for adaptive evolution in the recepto...
# 1  Detection of SARS-CoV-2 virus via dynamic ligh...
# 2  Reshaping Community Mental Health Services dur...
# 3  Decarcerating correctional facilities during C...
# 4  Preventive Behaviors Conveyed on YouTube to Mi...
#
#                              doi       pmcid pubmed_id   license  \
# 0      10.1101/2020.10.30.352914         NaN       NaN   biorxiv
# 1  10.1016/j.talanta.2022.123355  PMC8895652  35272155     no-cc
# 2       10.1177/1178632920954876  PMC7495522  32973373  cc-by-nc
# 3                 10.17226/25945         NaN       NaN       unk
# 4                  10.2196/18807  PMC7124952  32240096     cc-by
#
#                                             abstract publish_time  \
# 0  Seasonal coronaviruses (OC43, 229E, NL63 and H...   2020-10-30
# 1  Mass testing for the diagnosis of COVID-19 has...   2022-06-01
# 2  The COVID-19 pandemic led to a rapid transform...   2020-09-10
# 3  The conditions and characteristics of correcti...         2021
# 4  BACKGROUND: Accurate information and guidance ...   2020-04-02
#
#                                              authors  \
# 0               Kistler, Kathryn E.; Bedford, Trevor
# 1  Silva, Patricia Bento da; Silva, Jaqueline Rod...
# 2  Antoine, Baleige; Nicolas, Daumerie; Laurent, ...
# 3  Wang, E. A.; Western, B.; Backes, E. P.; Schuc...
# 4  Basch, Corey H; Hillyer, Grace C; Meleo-Erwin,...
#
#                                              journal mag_id  \
# 0                                            bioRxiv    NaN
# 1                                            Talanta    NaN
# 2                               Health Serv Insights    NaN
# 3  Decarcerating Correctional Facilities during C...    NaN
# 4                        JMIR Public Health Surveill    NaN
#
#     who_covidence_id arxiv_id  label       time       timet  \
# 0                NaN      NaN      0 2020-10-30  1604016000
# 1                NaN      NaN      0 2022-06-01  1654041600
# 2                NaN      NaN      0 2020-09-10  1599696000
# 3  #covidwho-1308567      NaN      0 2021-01-01  1609459200
# 4                NaN      NaN      0 2020-04-02  1585785600
#
#                                                query
# 0  A peer-reviewed study reveals no substantial a...
# 1  A peer-reviewed study reveals no substantial a...
# 2  A peer-reviewed study reveals no substantial a...
# 3  A peer-reviewed study reveals no substantial a...
# 4  A peer-reviewed study reveals no substantial a...

# %%
NUM_NEGATIVE_SAMPLES = 5

negative_test_data = pd.DataFrame(columns=df_collection.columns)
query = []

for idx, row in df_test_set.iterrows():
    entry_cord_id = row.cord_uid
    repeated_queries = [row.tweet_text] * NUM_NEGATIVE_SAMPLES
    query += repeated_queries
    negative_samples = df_collection.loc[df_collection["cord_uid"] != entry_cord_id]
    negative_samples = negative_samples.sample(NUM_NEGATIVE_SAMPLES)
    negative_test_data = pd.concat([negative_test_data, negative_samples], ignore_index=True)

cls = [0] * len(negative_test_data)
negative_test_data["label"] = cls
negative_test_data["query"] = query
negative_test_data.head()
# Out:
# /tmp/ipykernel_4039/3514562953.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   negative_test_data = pd.concat([negative_test_data, negative_samples], ignore_index=True)
#    cord_uid           source_x  \
# 0  f6nrqr1f       Medline; PMC
# 1  9zrcdurq  Medline; PMC; WHO
# 2  r6943zpb       Medline; PMC
# 3  omz42d9y  Elsevier; Medline
# 4  atji1xge       Medline; PMC
#
#                                                title  \
# 0  Mefloquine, a Potent Anti-severe Acute Respira...
# 1  Risk factors of mortality among patients hospi...
# 2  Vitamin D Deficiency and Outcome of COVID-19 P...
# 3  White-matter alterations are associated with c...
# 4  Joint Investigation of 2-Month Post-diagnosis ...
#
#                            doi       pmcid pubmed_id    license  \
# 0    10.3389/fmicb.2021.651403  PMC8119653  33995308      cc-by
# 1  10.1136/bmjresp-2021-001002  PMC8557246  34711641   cc-by-nc
# 2           10.3390/nu12092757  PMC7551780  32927735      cc-by
# 3   10.1016/j.bpsc.2021.04.014         NaN  33957321  els-covid
# 4    10.3389/fpubh.2020.590096  PMC7884822  33604323      cc-by
#
#                                             abstract publish_time  \
# 0  Coronavirus disease 2019 (COVID-19) has caused...   2021-04-30
# 1  OBJECTIVE: To explore mortality risk factors f...   2021-10-28
# 2  Infection with the severe acute respiratory sy...   2020-09-10
# 3  Background Possible white matter (WM) alterati...   2021-05-04
# 4  Following the outbreak of COVID-19, multidisci...   2021-02-02
#
#                                              authors  \
# 0  Shionoya, Kaho; Yamasaki, Masako; Iwanami, Sho...
# 1  Ouattara, Eric; Bruandet, Amelie; Borde, Aurél...
# 2  Radujkovic, Aleksandar; Hippchen, Theresa; Tiw...
# 3  Mohamed, Abdalla Z.; Cumming, Paul; Nasrallah,...
# 4  Barin, Burc; Yoldascan, Banu Elcin; Savaskan, ...
#
#                                              journal mag_id who_covidence_id  \
# 0                                    Front Microbiol    NaN              NaN
# 1                                BMJ Open Respir Res    NaN              NaN
# 2                                          Nutrients    NaN              NaN
# 3  Biological psychiatry. Cognitive neuroscience ...    NaN              NaN
# 4                                Front Public Health    NaN              NaN
#
#   arxiv_id  label       time       timet  \
# 0      NaN      0 2021-04-30  1619740800
# 1      NaN      0 2021-10-28  1635379200
# 2      NaN      0 2020-09-10  1599696000
# 3      NaN      0 2021-05-04  1620086400
# 4      NaN      0 2021-02-02  1612224000
#
#                                                query
# 0  5. "we did not discover evidence that surgical...
# 1  5. "we did not discover evidence that surgical...
# 2  5. "we did not discover evidence that surgical...
# 3  5. "we did not discover evidence that surgical...
# 4  5. "we did not discover evidence that surgical...

# %%
mixed_training_set = pd.concat([negative_train_data, positive_train_data], ignore_index=True)
mixed_training_set.info()

mixed_training_set.to_csv('data/train/tweets-query-pairs.tsv',sep='\t')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68412 entries, 0 to 68411
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cord_uid          68412 non-null  object
#  1   source_x          68412 non-null  object
#  2   title             68412 non-null  object
#  3   doi               68077 non-null  object
#  4   pmcid             44258 non-null  object
#  5   pubmed_id         55474 non-null  object
#  6   license           68412 non-null  object
#  7   abstract          68412 non-null  object
#  8   publish_time      68391 non-null  object
#  9   authors           67999 non-null  object
#  10  journal           59111 non-null  object
#  11  mag_id            0 non-null      object
#  12  who_covidence_id  4492 non-null   object
#  13  arxiv_id          196 non-null    object
#  14  label             68412 non-null  int64
#  15  time              68391 non-null  datetime64[ns]
#  16  timet             68412 non-null  object
#  17  query             68412 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(16)
# memory usage: 9.4+ MB

# %%
mixed_test_set = pd.concat([negative_test_data, positive_test_data], ignore_index=True)
mixed_test_set.info()

mixed_test_set.to_csv('data/test/tweets-query-pairs.tsv',sep='\t')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17106 entries, 0 to 17105
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cord_uid          17106 non-null  object
#  1   source_x          17106 non-null  object
#  2   title             17106 non-null  object
#  3   doi               17022 non-null  object
#  4   pmcid             10981 non-null  object
#  5   pubmed_id         13749 non-null  object
#  6   license           17106 non-null  object
#  7   abstract          17106 non-null  object
#  8   publish_time      17097 non-null  object
#  9   authors           17014 non-null  object
#  10  journal           14694 non-null  object
#  11  mag_id            0 non-null      object
#  12  who_covidence_id  1151 non-null   object
#  13  arxiv_id          53 non-null     object
#  14  label             17106 non-null  int64
#  15  time              17097 non-null  datetime64[ns]
#  16  timet             17106 non-null  object
#  17  query             17106 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(16)
# memory usage: 2.3+ MB
